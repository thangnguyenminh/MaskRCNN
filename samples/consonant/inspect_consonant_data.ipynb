# %% [markdown]
# # Mask R-CNN - Inspect Balloon Training Data
#
# Inspect and visualize data loading and pre-processing code.

# %%
from google.colab import drive
import os
import sys

drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/Mask_RCNN/samples/consonant')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import sys
import itertools
import math
import logging
import json
import re
import random
from collections import OrderedDict
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.lines as lines
from matplotlib.patches import Polygon

# Root directory of the project
ROOT_DIR = os.path.abspath("../../")

# # Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library

from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log

import consonant

# %matplotlib inline
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/Mask_RCNN/mrcnn/model.py:36: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Mask_RCNN/mrcnn/model.py:38: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# Using TensorFlow backend.

# %% [markdown]
# ## Configurations
#
# Configurations are defined in consonant.py

# %%
config = consonant.glyphConfig()
GLYPH_DIR = os.path.join(ROOT_DIR, "datasets/na_noise/RGB/train")

# %% [markdown]
# ## Dataset

# %%
# Load dataset
# Get the dataset from the releases page
# https://github.com/matterport/Mask_RCNN/releases
dataset = consonant.glyphDataset()
dataset.load_glyph(GLYPH_DIR, "train")

# Must call before using the dataset
dataset.prepare()

print("Image Count: {}".format(len(dataset.image_ids)))
print("Class Count: {}".format(dataset.num_classes))
for i, info in enumerate(dataset.class_info):
    print("{:3}. {:50}".format(i, info['name']))
# Out:
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line5-cr-letter22.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line10-cr-letter38.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line2-cr-letter14.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line3-cr-letter24.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line4-cr-letter24.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line5-cr-letter25.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line13-cr-letter18.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line18-cr-letter6.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 B-or-line8-cr-letter3.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 B-or-line12-cr-letter16.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 B-or-line22-cr-letter10.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line3-cr-letter4.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line10-cr-letter11.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line11-cr-letter25.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line12-cr-letter19.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line14-cr-letter5.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line15-cr-letter25.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line16-cr-letter13.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line16-cr-letter32.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line19-cr-letter18.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 B-or-line13-cr-letter14.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 E-or-line9-cr-letter9.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line6-cr-letter37.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line17-cr-letter21.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line17-cr-letter39.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line19-cr-letter49.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line22-cr-letter21.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 B-or-line22-cr-letter13.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line19-cr-letter36.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 D-or-line9-cr-letter8.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 E-or-line3-cr-letter2.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 E-or-line5-cr-letter3.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 E-or-line6-cr-letter13.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 E-or-line12-cr-letter6.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line3-cr-letter22.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line7-cr-letter18.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line5-cr-letter30.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line8-cr-letter7.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 E-or-line5-cr-letter6.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-29-B-line3-cr-letter12.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-29-B-line5-cr-letter10.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-29-B-line7-cr-letter3.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line11-cr-letter2.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 E-or-line5-cr-letter12.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 136-line1-cr-letter16.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 136-line1-cr-letter18.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 137-line4-cr-letter16.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-138-B-line1-cr-letter14.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-138-B-line2-cr-letter3.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-138-B-line2-cr-letter8.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-138-B-line2-cr-letter28.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-138-B-line2-cr-letter33.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-138-B-line5-cr-letter16.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-138-B-line6-cr-letter26.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line4-cr-letter20.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line8-cr-letter7.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line8-cr-letter16.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line9-cr-letter26.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line12-cr-letter14.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line12-cr-letter27.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line14-cr-letter1-letter1.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line6-cr-letter4.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line8-cr-letter12.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line8-cr-letter14.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line8-cr-letter17.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line10-cr-letter6.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line12-cr-letter29.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line14-cr-letter3.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line14-cr-letter14.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line20-cr-letter6.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line2-cr-letter2.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line4-cr-letter17.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line9-cr-letter29.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line10-cr-letter20.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line11-cr-letter18.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line15-cr-letter49.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line16-cr-letter9.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line19-cr-letter21.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line20-cr-letter48.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 B-or-line8-cr-letter31.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line8-cr-letter21.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line11-cr-letter27.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line11-cr-letter33.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line13-cr-letter45.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line16-cr-letter46.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line18-cr-letter10.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 B-or-line5-cr-letter6.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 B-or-line9-cr-letter26.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 B-or-line13-cr-letter12.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line17-cr-letter9.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line17-cr-letter31.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line17-cr-letter51.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line19-cr-letter7.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line20-cr-letter33.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line22-cr-letter44.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 D-or-line6-cr-letter7.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 D-or-line11-cr-letter1.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line1-cr-letter7.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line7-cr-letter10.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line8-cr-letter35.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line10-cr-letter12.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line11-cr-letter18.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line12-cr-letter15.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-29-B-line1-cr-letter1.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line5-cr-letter9.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 136-line1-cr-letter20.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 136-line1-cr-letter26.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 136-line2-cr-letter7.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 137-line1-cr-letter8.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 137-line1-cr-letter25.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 137-line2-cr-letter15.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 E-or-line2-cr-letter7.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 E-or-line8-cr-letter3.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 38 E-or-line8-cr-letter11.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-138-B-line3-cr-letter3.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-138-B-line4-cr-letter20.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-138-B-line6-cr-letter5.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-138-B-line6-cr-letter13.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line1-cr-letter2.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line6-cr-letter29.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line7-cr-letter27.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line13-cr-letter1.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line13-cr-letter10.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line13-cr-letter16.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line8-cr-letter37.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line10-cr-letter19.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line10-cr-letter24.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line11-cr-letter16.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line13-cr-letter23.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-148-A-line14-cr-letter21.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-171-A-line3-cr-letter7.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-171-A-line3-cr-letter17.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line17-cr-letter44.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line18-cr-letter22.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line19-cr-letter46.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line20-cr-letter46.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line21-cr-letter11.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line21-cr-letter40.png
# /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C 24A-line22-cr-letter38.png
# Image Count: 139
# Class Count: 2
#   0. BG
#   1. n

# %% [markdown]
# ## Display Samples
#
# Load and display images and masks.

# %%
# Load and display random samples
image_ids = np.random.choice(dataset.image_ids, 4)
for image_id in image_ids:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset.class_names)

# %% [markdown]
# ## Bounding Boxes
#
# Rather than using bounding box coordinates provided by the source datasets, we compute the bounding boxes from masks instead. This allows us to handle bounding boxes consistently regardless of the source dataset, and it also makes it easier to resize, rotate, or crop images because we simply generate the bounding boxes from the updates masks rather than computing bounding box transformation for each type of image transformation.

# %%
# Load random image and mask.
#image_id = random.choice(dataset.image_ids)
#image_id = 143 # 1 components
image_id = 57 # several components
image = dataset.load_image(image_id)
mask, class_ids = dataset.load_mask(image_id)
# Compute Bounding box
bbox = utils.extract_bboxes(mask)

# Display image and additional stats
print("image_id ", image_id, dataset.image_reference(image_id))
log("image", image)
log("mask", mask)
log("class_ids", class_ids)
log("bbox", bbox)
# Display image and instances
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)
# Out:
# image_id  57 /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-141-A-line9-cr-letter26.png
# image                    shape: (125, 49, 3)          min:    7.00000  max:  239.00000  uint8
# mask                     shape: (125, 49, 1)          min:    0.00000  max:    1.00000  uint8
# class_ids                shape: (1,)                  min:    1.00000  max:    1.00000  int32
# bbox                     shape: (1, 4)                min:    3.00000  max:  123.00000  int32

# %% [markdown]
# ## Resize Images
#
# To support multiple images per batch, images are resized to one size (1024x1024). Aspect ratio is preserved, though. If an image is not square, then zero padding is added at the top/bottom or right/left.

# %%
# Load random image and mask.
image_id = np.random.choice(dataset.image_ids, 1)[0]
image = dataset.load_image(image_id)
mask, class_ids = dataset.load_mask(image_id)
original_shape = image.shape
# Resize
image, window, scale, padding, _ = utils.resize_image(
    image, 
    min_dim=config.IMAGE_MIN_DIM, 
    max_dim=config.IMAGE_MAX_DIM,
    mode=config.IMAGE_RESIZE_MODE)
mask = utils.resize_mask(mask, scale, padding)
# Compute Bounding box
bbox = utils.extract_bboxes(mask)

# Display image and additional stats
print("image_id: ", image_id, dataset.image_reference(image_id))
print("Original shape: ", original_shape)
log("image", image)
log("mask", mask)
log("class_ids", class_ids)
log("bbox", bbox)
# Display image and instances
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)
# Out:
# image_id:  41 /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-29-B-line7-cr-letter3.png
# Original shape:  (188, 168, 3)
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  200.00000  uint8
# mask                     shape: (1024, 1024, 1)       min:    0.00000  max:    1.00000  uint8
# class_ids                shape: (1,)                  min:    1.00000  max:    1.00000  int32
# bbox                     shape: (1, 4)                min:  129.00000  max:  904.00000  int32

# %% [markdown]
# ## Mini Masks
#
# Instance binary masks can get large when training with high resolution images. For example, if training with 1024x1024 image then the mask of a single instance requires 1MB of memory (Numpy uses bytes for boolean values). If an image has 100 instances then that's 100MB for the masks alone.
#
# To improve training speed, we optimize masks by:
# * We store mask pixels that are inside the object bounding box, rather than a mask of the full image. Most objects are small compared to the image size, so we save space by not storing a lot of zeros around the object.
# * We resize the mask to a smaller size (e.g. 56x56). For objects that are larger than the selected size we lose a bit of accuracy. But most object annotations are not very accuracy to begin with, so this loss is negligable for most practical purposes. Thie size of the mini_mask can be set in the config class.
#
# To visualize the effect of mask resizing, and to verify the code correctness, we visualize some examples.

# %%
image_id = np.random.choice(dataset.image_ids, 1)[0]
image, image_meta, class_ids, bbox, mask = modellib.load_image_gt(
    dataset, config, image_id, use_mini_mask=False)

log("image", image)
log("image_meta", image_meta)
log("class_ids", class_ids)
log("bbox", bbox)
log("mask", mask)

display_images([image]+[mask[:,:,i] for i in range(min(mask.shape[-1], 7))])
# Out:
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# image_meta               shape: (14,)                 min:    0.00000  max: 1024.00000  float64
# class_ids                shape: (1,)                  min:    1.00000  max:    1.00000  int32
# bbox                     shape: (1, 4)                min:   67.00000  max:  993.00000  int32
# mask                     shape: (1024, 1024, 1)       min:    0.00000  max:    1.00000  uint8

# %%
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)

# %%
# Add augmentation and mask resizing.
image, image_meta, class_ids, bbox, mask = modellib.load_image_gt(
    dataset, config, image_id, augment=True, use_mini_mask=True)
log("mask", mask)
display_images([image]+[mask[:,:,i] for i in range(min(mask.shape[-1], 7))])
# Out:
# WARNING:root:'augment' is deprecated. Use 'augmentation' instead.
# mask                     shape: (56, 56, 1)           min:    0.00000  max:    1.00000  bool

# %%
mask = utils.expand_mask(bbox, mask, image.shape)
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)

# %% [markdown]
# ## Anchors
#
# The order of anchors is important. Use the same order in training and prediction phases. And it must match the order of the convolution execution.
#
# For an FPN network, the anchors must be ordered in a way that makes it easy to match anchors to the output of the convolution layers that predict anchor scores and shifts.
# * Sort by pyramid level first. All anchors of the first level, then all of the second and so on. This makes it easier to separate anchors by level.
# * Within each level, sort anchors by feature map processing sequence. Typically, a convolution layer processes a feature map starting from top-left and moving right row by row.
# * For each feature map cell, pick any sorting order for the anchors of different ratios. Here we match the order of ratios passed to the function.
#
# **Anchor Stride:**
# In the FPN architecture, feature maps at the first few layers are high resolution. For example, if the input image is 1024x1024 then the feature meap of the first layer is 256x256, which generates about 200K anchors (256*256*3). These anchors are 32x32 pixels and their stride relative to image pixels is 4 pixels, so there is a lot of overlap. We can reduce the load significantly if we generate anchors for every other cell in the feature map. A stride of 2 will cut the number of anchors by 4, for example.
#
# In this implementation we use an anchor stride of 2, which is different from the paper.

# %%
# Generate Anchors
backbone_shapes = modellib.compute_backbone_shapes(config, config.IMAGE_SHAPE)
anchors = utils.generate_pyramid_anchors(config.RPN_ANCHOR_SCALES, 
                                          config.RPN_ANCHOR_RATIOS,
                                          backbone_shapes,
                                          config.BACKBONE_STRIDES, 
                                          config.RPN_ANCHOR_STRIDE)

# Print summary of anchors
num_levels = len(backbone_shapes)
anchors_per_cell = len(config.RPN_ANCHOR_RATIOS)
print("Count: ", anchors.shape[0])
print("Scales: ", config.RPN_ANCHOR_SCALES)
print("ratios: ", config.RPN_ANCHOR_RATIOS)
print("Anchors per Cell: ", anchors_per_cell)
print("Levels: ", num_levels)
anchors_per_level = []
for l in range(num_levels):
    num_cells = backbone_shapes[l][0] * backbone_shapes[l][1]
    anchors_per_level.append(anchors_per_cell * num_cells // config.RPN_ANCHOR_STRIDE**2)
    print("Anchors in Level {}: {}".format(l, anchors_per_level[l]))
# Out:
# Count:  261888
# Scales:  (32, 64, 128, 256, 512)
# ratios:  [0.5, 1, 2]
# Anchors per Cell:  3
# Levels:  5
# Anchors in Level 0: 196608
# Anchors in Level 1: 49152
# Anchors in Level 2: 12288
# Anchors in Level 3: 3072
# Anchors in Level 4: 768

# %% [markdown]
# Visualize anchors of one cell at the center of the feature map of a specific level.

# %%
## Visualize anchors of one cell at the center of the feature map of a specific level

# Load and draw random image
image_id = np.random.choice(dataset.image_ids, 1)[0]
image, image_meta, _, _, _ = modellib.load_image_gt(dataset, config, image_id)
fig, ax = plt.subplots(1, figsize=(10, 10))
ax.imshow(image)
levels = len(backbone_shapes)

for level in range(levels):
    colors = visualize.random_colors(levels)
    # Compute the index of the anchors at the center of the image
    level_start = sum(anchors_per_level[:level]) # sum of anchors of previous levels
    level_anchors = anchors[level_start:level_start+anchors_per_level[level]]
    print("Level {}. Anchors: {:6}  Feature map Shape: {}".format(level, level_anchors.shape[0], 
                                                                  backbone_shapes[level]))
    center_cell = backbone_shapes[level] // 2
    center_cell_index = (center_cell[0] * backbone_shapes[level][1] + center_cell[1])
    level_center = center_cell_index * anchors_per_cell 
    center_anchor = anchors_per_cell * (
        (center_cell[0] * backbone_shapes[level][1] / config.RPN_ANCHOR_STRIDE**2) \
        + center_cell[1] / config.RPN_ANCHOR_STRIDE)
    level_center = int(center_anchor)

    # Draw anchors. Brightness show the order in the array, dark to bright.
    for i, rect in enumerate(level_anchors[level_center:level_center+anchors_per_cell]):
        y1, x1, y2, x2 = rect
        p = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=2, facecolor='none',
                              edgecolor=(i+1)*np.array(colors[level]) / anchors_per_cell)
        ax.add_patch(p)
# Out:
# Level 0. Anchors: 196608  Feature map Shape: [256 256]
# Level 1. Anchors:  49152  Feature map Shape: [128 128]
# Level 2. Anchors:  12288  Feature map Shape: [64 64]
# Level 3. Anchors:   3072  Feature map Shape: [32 32]
# Level 4. Anchors:    768  Feature map Shape: [16 16]

# %% [markdown]
# ## Data Generator

# %%
# Create data generator
random_rois = 2000
g = modellib.data_generator(
    dataset, config, shuffle=True, random_rois=random_rois, 
    batch_size=4,
    detection_targets=True)

# %%
# Uncomment to run the generator through a lot of images
# to catch rare errors
# for i in range(1000):
#     print(i)
#     _, _ = next(g)

# %%
# Get Next Image
if random_rois:
    [normalized_images, image_meta, rpn_match, rpn_bbox, gt_class_ids, gt_boxes, gt_masks, rpn_rois, rois], \
    [mrcnn_class_ids, mrcnn_bbox, mrcnn_mask] = next(g)
    
    log("rois", rois)
    log("mrcnn_class_ids", mrcnn_class_ids)
    log("mrcnn_bbox", mrcnn_bbox)
    log("mrcnn_mask", mrcnn_mask)
else:
    [normalized_images, image_meta, rpn_match, rpn_bbox, gt_boxes, gt_masks], _ = next(g)
    
log("gt_class_ids", gt_class_ids)
log("gt_boxes", gt_boxes)
log("gt_masks", gt_masks)
log("rpn_match", rpn_match, )
log("rpn_bbox", rpn_bbox)
image_id = modellib.parse_image_meta(image_meta)["image_id"][0]
print("image_id: ", image_id, dataset.image_reference(image_id))

# Remove the last dim in mrcnn_class_ids. It's only added
# to satisfy Keras restriction on target shape.
mrcnn_class_ids = mrcnn_class_ids[:,:,0]
# Out:
# rois                     shape: (4, 200, 4)           min:    0.00000  max: 1023.00000  int32
# mrcnn_class_ids          shape: (4, 200, 1)           min:    0.00000  max:    1.00000  int32
# mrcnn_bbox               shape: (4, 200, 2, 4)        min:   -3.40830  max:    4.02263  float32
# mrcnn_mask               shape: (4, 200, 28, 28, 2)   min:    0.00000  max:    1.00000  float32
# gt_class_ids             shape: (4, 100)              min:    0.00000  max:    1.00000  int32
# gt_boxes                 shape: (4, 100, 4)           min:    0.00000  max:  993.00000  int32
# gt_masks                 shape: (4, 56, 56, 100)      min:    0.00000  max:    1.00000  bool
# rpn_match                shape: (4, 261888, 1)        min:   -1.00000  max:    1.00000  int32
# rpn_bbox                 shape: (4, 256, 4)           min:   -2.88086  max:    3.36914  float64
# image_id:  51 /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/C-138-B-line2-cr-letter33.png

# %%
b = 0

# Restore original image (reverse normalization)
sample_image = modellib.unmold_image(normalized_images[b], config)

# Compute anchor shifts.
indices = np.where(rpn_match[b] == 1)[0]
refined_anchors = utils.apply_box_deltas(anchors[indices], rpn_bbox[b, :len(indices)] * config.RPN_BBOX_STD_DEV)
log("anchors", anchors)
log("refined_anchors", refined_anchors)

# Get list of positive anchors
positive_anchor_ids = np.where(rpn_match[b] == 1)[0]
print("Positive anchors: {}".format(len(positive_anchor_ids)))
negative_anchor_ids = np.where(rpn_match[b] == -1)[0]
print("Negative anchors: {}".format(len(negative_anchor_ids)))
neutral_anchor_ids = np.where(rpn_match[b] == 0)[0]
print("Neutral anchors: {}".format(len(neutral_anchor_ids)))

# ROI breakdown by class
for c, n in zip(dataset.class_names, np.bincount(mrcnn_class_ids[b].flatten())):
    if n:
        print("{:23}: {}".format(c[:20], n))

# Show positive anchors
fig, ax = plt.subplots(1, figsize=(16, 16))
visualize.draw_boxes(sample_image, boxes=anchors[positive_anchor_ids], 
                     refined_boxes=refined_anchors, ax=ax)
# Out:
# anchors                  shape: (261888, 4)           min: -362.03867  max: 1322.03867  float64
# refined_anchors          shape: (4, 4)                min:   94.00000  max:  892.00000  float32
# Positive anchors: 4
# Negative anchors: 252
# Neutral anchors: 261632
# BG                     : 134
# n                      : 66

# %%
# Show negative anchors
visualize.draw_boxes(sample_image, boxes=anchors[negative_anchor_ids])

# %%
# Show neutral anchors. They don't contribute to training.
visualize.draw_boxes(sample_image, boxes=anchors[np.random.choice(neutral_anchor_ids, 100)])

# %% [markdown]
# ## ROIs

# %%
if random_rois:
    # Class aware bboxes
    bbox_specific = mrcnn_bbox[b, np.arange(mrcnn_bbox.shape[1]), mrcnn_class_ids[b], :]

    # Refined ROIs
    refined_rois = utils.apply_box_deltas(rois[b].astype(np.float32), bbox_specific[:,:4] * config.BBOX_STD_DEV)

    # Class aware masks
    mask_specific = mrcnn_mask[b, np.arange(mrcnn_mask.shape[1]), :, :, mrcnn_class_ids[b]]

    visualize.draw_rois(sample_image, rois[b], refined_rois, mask_specific, mrcnn_class_ids[b], dataset.class_names)
    
    # Any repeated ROIs?
    rows = np.ascontiguousarray(rois[b]).view(np.dtype((np.void, rois.dtype.itemsize * rois.shape[-1])))
    _, idx = np.unique(rows, return_index=True)
    print("Unique ROIs: {} out of {}".format(len(idx), rois.shape[1]))
# Out:
# Positive ROIs:  66
# Negative ROIs:  134
# Positive Ratio: 0.33
# Unique ROIs: 200 out of 200

# %%
if random_rois:
    # Dispalay ROIs and corresponding masks and bounding boxes
    ids = random.sample(range(rois.shape[1]), 8)

    images = []
    titles = []
    for i in ids:
        image = visualize.draw_box(sample_image.copy(), rois[b,i,:4].astype(np.int32), [255, 0, 0])
        image = visualize.draw_box(image, refined_rois[i].astype(np.int64), [0, 255, 0])
        images.append(image)
        titles.append("ROI {}".format(i))
        images.append(mask_specific[i] * 255)
        titles.append(dataset.class_names[mrcnn_class_ids[b,i]][:20])

    display_images(images, titles, cols=4, cmap="Blues", interpolation="none")

# %%
# Check ratio of positive ROIs in a set of images.
if random_rois:
    limit = 10
    temp_g = modellib.data_generator(
        dataset, config, shuffle=True, random_rois=10000, 
        batch_size=1, detection_targets=True)
    total = 0
    for i in range(limit):
        _, [ids, _, _] = next(temp_g)
        positive_rois = np.sum(ids[0] > 0)
        total += positive_rois
        print("{:5} {:5.2f}".format(positive_rois, positive_rois/ids.shape[1]))
    print("Average percent: {:.2f}".format(total/(limit*ids.shape[1])))
# Out:
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
#    66  0.33
# Average percent: 0.33

# %%
# !python3 consonant.py train --dataset=/content/drive/My\ Drive/Mask_RCNN/datasets/na_noise/RGB/train/ --weights=coco
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /content/drive/My Drive/Mask_RCNN/mrcnn/model.py:36: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Mask_RCNN/mrcnn/model.py:38: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-09-19 10:34:38.075974: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-09-19 10:34:38.076192: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x28b2a00 executing computations on platform Host. Devices:
# 2019-09-19 10:34:38.076228: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-09-19 10:34:38.078381: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcuda.so.1
# 2019-09-19 10:34:38.125337: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-09-19 10:34:38.126201: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x28b2bc0 executing computations on platform CUDA. Devices:
# 2019-09-19 10:34:38.126233: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2019-09-19 10:34:38.126455: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-09-19 10:34:38.127115: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1640] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2019-09-19 10:34:38.127453: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-09-19 10:34:38.128866: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-09-19 10:34:38.130101: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcufft.so.10.0
# 2019-09-19 10:34:38.130571: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcurand.so.10.0
# 2019-09-19 10:34:38.132162: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusolver.so.10.0
# 2019-09-19 10:34:38.133460: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcusparse.so.10.0
# 2019-09-19 10:34:38.137221: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-09-19 10:34:38.137339: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-09-19 10:34:38.138079: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-09-19 10:34:38.138793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1763] Adding visible gpu devices: 0
# 2019-09-19 10:34:38.138850: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudart.so.10.0
# 2019-09-19 10:34:38.140324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1181] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-09-19 10:34:38.140385: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1187]      0
# 2019-09-19 10:34:38.140399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1200] 0:   N
# 2019-09-19 10:34:38.140532: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-09-19 10:34:38.141276: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1005] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-09-19 10:34:38.142052: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:40] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2019-09-19 10:34:38.142095: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1326] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 4576 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Weights:  coco
# Dataset:  /content/drive/My Drive/Mask_RCNN/datasets/na_noise/RGB/train/
# Logs:  /content/drive/My Drive/Mask_RCNN/logs
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           glyph
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001
#
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2139: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/drive/My Drive/Mask_RCNN/mrcnn/model.py:610: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# Loading weights  /content/drive/My Drive/Mask_RCNN/mask_rcnn_coco.h5
# Training network heads
#
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /content/drive/My Drive/Mask_RCNN/logs/glyph20190919T1034/mask_rcnn_glyph_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1122: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1125: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/30
# 2019-09-19 10:35:16.832660: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1412] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
# 2019-09-19 10:35:18.053188: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcublas.so.10.0
# 2019-09-19 10:35:18.886330: I tensorflow/stream_executor/platform/default/dso_loader.cc:42] Successfully opened dynamic library libcudnn.so.7
# 2019-09-19 10:35:27.372154: W tensorflow/core/common_runtime/bfc_allocator.cc:237] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-09-19 10:35:28.469159: W tensorflow/core/common_runtime/bfc_allocator.cc:237] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.69GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-09-19 10:35:28.569924: W tensorflow/core/common_runtime/bfc_allocator.cc:237] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-09-19 10:35:29.188851: W tensorflow/core/common_runtime/bfc_allocator.cc:237] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.10GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-09-19 10:35:30.331334: W tensorflow/core/common_runtime/bfc_allocator.cc:237] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.03GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2019-09-19 10:35:30.358009: W tensorflow/core/common_runtime/bfc_allocator.cc:237] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.03GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 100/100 [==============================] - 183s 2s/step - loss: 1.7714 - rpn_class_loss: 0.0108 - rpn_bbox_loss: 0.5577 - mrcnn_class_loss: 0.0555 - mrcnn_bbox_loss: 0.6307 - mrcnn_mask_loss: 0.5166 - val_loss: 1.2119 - val_rpn_class_loss: 0.0065 - val_rpn_bbox_loss: 0.4031 - val_mrcnn_class_loss: 0.0251 - val_mrcnn_bbox_loss: 0.3147 - val_mrcnn_mask_loss: 0.4626
# Epoch 2/30
# 100/100 [==============================] - 149s 1s/step - loss: 1.1990 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.3826 - mrcnn_class_loss: 0.0306 - mrcnn_bbox_loss: 0.3365 - mrcnn_mask_loss: 0.4432 - val_loss: 1.0730 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.3403 - val_mrcnn_class_loss: 0.0268 - val_mrcnn_bbox_loss: 0.2929 - val_mrcnn_mask_loss: 0.4061
# Epoch 3/30
# 100/100 [==============================] - 149s 1s/step - loss: 1.1364 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.3888 - mrcnn_class_loss: 0.0257 - mrcnn_bbox_loss: 0.3088 - mrcnn_mask_loss: 0.4063 - val_loss: 0.9522 - val_rpn_class_loss: 0.0090 - val_rpn_bbox_loss: 0.2867 - val_mrcnn_class_loss: 0.0310 - val_mrcnn_bbox_loss: 0.2247 - val_mrcnn_mask_loss: 0.4008
# Epoch 4/30
# 100/100 [==============================] - 149s 1s/step - loss: 0.9569 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.3369 - mrcnn_class_loss: 0.0258 - mrcnn_bbox_loss: 0.2199 - mrcnn_mask_loss: 0.3677 - val_loss: 0.8736 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 0.2847 - val_mrcnn_class_loss: 0.0229 - val_mrcnn_bbox_loss: 0.2008 - val_mrcnn_mask_loss: 0.3593
# Epoch 5/30
# 100/100 [==============================] - 149s 1s/step - loss: 0.8731 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.2799 - mrcnn_class_loss: 0.0249 - mrcnn_bbox_loss: 0.2060 - mrcnn_mask_loss: 0.3559 - val_loss: 0.7812 - val_rpn_class_loss: 0.0054 - val_rpn_bbox_loss: 0.2722 - val_mrcnn_class_loss: 0.0225 - val_mrcnn_bbox_loss: 0.1515 - val_mrcnn_mask_loss: 0.3296
# Epoch 6/30
# 100/100 [==============================] - 148s 1s/step - loss: 0.7916 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.2641 - mrcnn_class_loss: 0.0215 - mrcnn_bbox_loss: 0.1733 - mrcnn_mask_loss: 0.3273 - val_loss: 0.7589 - val_rpn_class_loss: 0.0036 - val_rpn_bbox_loss: 0.2960 - val_mrcnn_class_loss: 0.0231 - val_mrcnn_bbox_loss: 0.1438 - val_mrcnn_mask_loss: 0.2924
# Epoch 7/30
# 100/100 [==============================] - 149s 1s/step - loss: 0.7835 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.2690 - mrcnn_class_loss: 0.0237 - mrcnn_bbox_loss: 0.1709 - mrcnn_mask_loss: 0.3146 - val_loss: 0.7055 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 0.2321 - val_mrcnn_class_loss: 0.0206 - val_mrcnn_bbox_loss: 0.1377 - val_mrcnn_mask_loss: 0.3072
# Epoch 8/30
# 100/100 [==============================] - 148s 1s/step - loss: 0.7244 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.2550 - mrcnn_class_loss: 0.0212 - mrcnn_bbox_loss: 0.1407 - mrcnn_mask_loss: 0.3014 - val_loss: 0.6151 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 0.1928 - val_mrcnn_class_loss: 0.0179 - val_mrcnn_bbox_loss: 0.1181 - val_mrcnn_mask_loss: 0.2804
# Epoch 9/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.6786 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.2395 - mrcnn_class_loss: 0.0208 - mrcnn_bbox_loss: 0.1329 - mrcnn_mask_loss: 0.2798 - val_loss: 0.6510 - val_rpn_class_loss: 0.0045 - val_rpn_bbox_loss: 0.2040 - val_mrcnn_class_loss: 0.0225 - val_mrcnn_bbox_loss: 0.1430 - val_mrcnn_mask_loss: 0.2770
# Epoch 10/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.6525 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.2065 - mrcnn_class_loss: 0.0210 - mrcnn_bbox_loss: 0.1364 - mrcnn_mask_loss: 0.2828 - val_loss: 0.5858 - val_rpn_class_loss: 0.0056 - val_rpn_bbox_loss: 0.1986 - val_mrcnn_class_loss: 0.0190 - val_mrcnn_bbox_loss: 0.0994 - val_mrcnn_mask_loss: 0.2632
# Epoch 11/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.6219 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.2116 - mrcnn_class_loss: 0.0212 - mrcnn_bbox_loss: 0.1160 - mrcnn_mask_loss: 0.2681 - val_loss: 0.5913 - val_rpn_class_loss: 0.0052 - val_rpn_bbox_loss: 0.2044 - val_mrcnn_class_loss: 0.0224 - val_mrcnn_bbox_loss: 0.0986 - val_mrcnn_mask_loss: 0.2607
# Epoch 12/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.5705 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.1855 - mrcnn_class_loss: 0.0179 - mrcnn_bbox_loss: 0.1079 - mrcnn_mask_loss: 0.2539 - val_loss: 0.4550 - val_rpn_class_loss: 0.0046 - val_rpn_bbox_loss: 0.1236 - val_mrcnn_class_loss: 0.0185 - val_mrcnn_bbox_loss: 0.0642 - val_mrcnn_mask_loss: 0.2441
# Epoch 13/30
# 100/100 [==============================] - 148s 1s/step - loss: 0.5925 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.2024 - mrcnn_class_loss: 0.0203 - mrcnn_bbox_loss: 0.1082 - mrcnn_mask_loss: 0.2580 - val_loss: 0.4815 - val_rpn_class_loss: 0.0050 - val_rpn_bbox_loss: 0.1298 - val_mrcnn_class_loss: 0.0218 - val_mrcnn_bbox_loss: 0.0872 - val_mrcnn_mask_loss: 0.2377
# Epoch 14/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.5129 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.1649 - mrcnn_class_loss: 0.0152 - mrcnn_bbox_loss: 0.0886 - mrcnn_mask_loss: 0.2391 - val_loss: 0.5476 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 0.1810 - val_mrcnn_class_loss: 0.0174 - val_mrcnn_bbox_loss: 0.1025 - val_mrcnn_mask_loss: 0.2407
# Epoch 15/30
# 100/100 [==============================] - 148s 1s/step - loss: 0.5154 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1607 - mrcnn_class_loss: 0.0189 - mrcnn_bbox_loss: 0.0920 - mrcnn_mask_loss: 0.2393 - val_loss: 0.5056 - val_rpn_class_loss: 0.0048 - val_rpn_bbox_loss: 0.1647 - val_mrcnn_class_loss: 0.0167 - val_mrcnn_bbox_loss: 0.0995 - val_mrcnn_mask_loss: 0.2199
# Epoch 16/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.4996 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.1603 - mrcnn_class_loss: 0.0186 - mrcnn_bbox_loss: 0.0826 - mrcnn_mask_loss: 0.2333 - val_loss: 0.4419 - val_rpn_class_loss: 0.0045 - val_rpn_bbox_loss: 0.1255 - val_mrcnn_class_loss: 0.0180 - val_mrcnn_bbox_loss: 0.0639 - val_mrcnn_mask_loss: 0.2300
# Epoch 17/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.4849 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.1413 - mrcnn_class_loss: 0.0172 - mrcnn_bbox_loss: 0.0852 - mrcnn_mask_loss: 0.2364 - val_loss: 0.4308 - val_rpn_class_loss: 0.0040 - val_rpn_bbox_loss: 0.0869 - val_mrcnn_class_loss: 0.0167 - val_mrcnn_bbox_loss: 0.0899 - val_mrcnn_mask_loss: 0.2333
# Epoch 18/30
# 100/100 [==============================] - 148s 1s/step - loss: 0.4695 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.1455 - mrcnn_class_loss: 0.0159 - mrcnn_bbox_loss: 0.0781 - mrcnn_mask_loss: 0.2256 - val_loss: 0.4068 - val_rpn_class_loss: 0.0035 - val_rpn_bbox_loss: 0.1114 - val_mrcnn_class_loss: 0.0182 - val_mrcnn_bbox_loss: 0.0635 - val_mrcnn_mask_loss: 0.2102
# Epoch 19/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.4407 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.1299 - mrcnn_class_loss: 0.0200 - mrcnn_bbox_loss: 0.0702 - mrcnn_mask_loss: 0.2168 - val_loss: 0.4112 - val_rpn_class_loss: 0.0034 - val_rpn_bbox_loss: 0.1102 - val_mrcnn_class_loss: 0.0162 - val_mrcnn_bbox_loss: 0.0645 - val_mrcnn_mask_loss: 0.2170
# Epoch 20/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.4125 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.1147 - mrcnn_class_loss: 0.0193 - mrcnn_bbox_loss: 0.0608 - mrcnn_mask_loss: 0.2134 - val_loss: 0.4207 - val_rpn_class_loss: 0.0032 - val_rpn_bbox_loss: 0.1231 - val_mrcnn_class_loss: 0.0218 - val_mrcnn_bbox_loss: 0.0627 - val_mrcnn_mask_loss: 0.2099
# Epoch 21/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.4253 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.1134 - mrcnn_class_loss: 0.0219 - mrcnn_bbox_loss: 0.0705 - mrcnn_mask_loss: 0.2160 - val_loss: 0.3866 - val_rpn_class_loss: 0.0046 - val_rpn_bbox_loss: 0.0957 - val_mrcnn_class_loss: 0.0228 - val_mrcnn_bbox_loss: 0.0727 - val_mrcnn_mask_loss: 0.1908
# Epoch 22/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.4131 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.1169 - mrcnn_class_loss: 0.0275 - mrcnn_bbox_loss: 0.0614 - mrcnn_mask_loss: 0.2030 - val_loss: 0.3765 - val_rpn_class_loss: 0.0041 - val_rpn_bbox_loss: 0.1072 - val_mrcnn_class_loss: 0.0222 - val_mrcnn_bbox_loss: 0.0460 - val_mrcnn_mask_loss: 0.1969
# Epoch 23/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.3995 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.1140 - mrcnn_class_loss: 0.0258 - mrcnn_bbox_loss: 0.0558 - mrcnn_mask_loss: 0.2004 - val_loss: 0.4099 - val_rpn_class_loss: 0.0039 - val_rpn_bbox_loss: 0.1125 - val_mrcnn_class_loss: 0.0209 - val_mrcnn_bbox_loss: 0.0713 - val_mrcnn_mask_loss: 0.2013
# Epoch 24/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.4113 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.1280 - mrcnn_class_loss: 0.0207 - mrcnn_bbox_loss: 0.0528 - mrcnn_mask_loss: 0.2064 - val_loss: 0.4021 - val_rpn_class_loss: 0.0043 - val_rpn_bbox_loss: 0.1316 - val_mrcnn_class_loss: 0.0216 - val_mrcnn_bbox_loss: 0.0629 - val_mrcnn_mask_loss: 0.1818
# Epoch 25/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.3949 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.1076 - mrcnn_class_loss: 0.0275 - mrcnn_bbox_loss: 0.0646 - mrcnn_mask_loss: 0.1914 - val_loss: 0.3677 - val_rpn_class_loss: 0.0040 - val_rpn_bbox_loss: 0.0783 - val_mrcnn_class_loss: 0.0300 - val_mrcnn_bbox_loss: 0.0601 - val_mrcnn_mask_loss: 0.1954
# Epoch 26/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.3544 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0909 - mrcnn_class_loss: 0.0276 - mrcnn_bbox_loss: 0.0475 - mrcnn_mask_loss: 0.1849 - val_loss: 0.3385 - val_rpn_class_loss: 0.0038 - val_rpn_bbox_loss: 0.0727 - val_mrcnn_class_loss: 0.0297 - val_mrcnn_bbox_loss: 0.0444 - val_mrcnn_mask_loss: 0.1880
# Epoch 27/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.3796 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0949 - mrcnn_class_loss: 0.0295 - mrcnn_bbox_loss: 0.0594 - mrcnn_mask_loss: 0.1924 - val_loss: 0.3709 - val_rpn_class_loss: 0.0049 - val_rpn_bbox_loss: 0.0883 - val_mrcnn_class_loss: 0.0263 - val_mrcnn_bbox_loss: 0.0577 - val_mrcnn_mask_loss: 0.1937
# Epoch 28/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.3680 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.0993 - mrcnn_class_loss: 0.0281 - mrcnn_bbox_loss: 0.0507 - mrcnn_mask_loss: 0.1856 - val_loss: 0.3646 - val_rpn_class_loss: 0.0036 - val_rpn_bbox_loss: 0.1169 - val_mrcnn_class_loss: 0.0288 - val_mrcnn_bbox_loss: 0.0422 - val_mrcnn_mask_loss: 0.1730
# Epoch 29/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.3561 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.0842 - mrcnn_class_loss: 0.0308 - mrcnn_bbox_loss: 0.0521 - mrcnn_mask_loss: 0.1852 - val_loss: 0.3293 - val_rpn_class_loss: 0.0047 - val_rpn_bbox_loss: 0.0697 - val_mrcnn_class_loss: 0.0312 - val_mrcnn_bbox_loss: 0.0455 - val_mrcnn_mask_loss: 0.1782
# Epoch 30/30
# 100/100 [==============================] - 147s 1s/step - loss: 0.3154 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.0712 - mrcnn_class_loss: 0.0246 - mrcnn_bbox_loss: 0.0378 - mrcnn_mask_loss: 0.1777 - val_loss: 0.3288 - val_rpn_class_loss: 0.0034 - val_rpn_bbox_loss: 0.0793 - val_mrcnn_class_loss: 0.0287 - val_mrcnn_bbox_loss: 0.0406 - val_mrcnn_mask_loss: 0.1768
